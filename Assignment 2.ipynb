# %% [markdown]
# # Answer 01

# %%
for i in range(21):
    if i%2 == 0:
        print("Even Number",i)
# Out:
# Even Number 0
# Even Number 2
# Even Number 4
# Even Number 6
# Even Number 8
# Even Number 10
# Even Number 12
# Even Number 14
# Even Number 16
# Even Number 18
# Even Number 20

# %% [markdown]
# # Answer 02

# %%
for i in range(1,21):
    if i%3 == 0:
        print("Odd Number",i)
# Out:
# Odd Number 3
# Odd Number 6
# Odd Number 9
# Odd Number 12
# Odd Number 15
# Odd Number 18

# %% [markdown]
# # Answer 03

# %%
for i in range(0,10):
    if i == 5:
        print("Five Found")
    else:
        print(i)
# Out:
# 0
# 1
# 2
# 3
# 4
# Five Found
# 6
# 7
# 8
# 9

# %% [markdown]
# # Answer 04

# %%
number=[3,8,12,1,9]
for i in number:
    if i > 5:
        print("Number Is Greater Than 5 ",i)
    else:
        ("Number Is Lower ")
# Out:
# Number Is Greater Than 5  8
# Number Is Greater Than 5  12
# Number Is Greater Than 5  9

# %% [markdown]
# # Answer 05

# %%
for i in range(1,15):
    if i%3 == 0:
        print("Number Is Divisible",i,sep='   ')
# Out:
# Number Is Divisible   3
# Number Is Divisible   6
# Number Is Divisible   9
# Number Is Divisible   12

# %% [markdown]
# # Answer 06

# %%
num_1=[2, -5, 10, -8, 0]
for i in num_1:
    if i > 0:
        print("Positive Number",i,sep='   ')
    elif i < 0:
        print("Negative Number",i,sep='   ')
    else:
        print(i)
# Out:
# Positive Number   2
# Negative Number   -5
# Positive Number   10
# Negative Number   -8
# 0

# %% [markdown]
# # Answer 07

# %%
for i in range(1,11):
    if i == 7:
        break
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6

# %% [markdown]
# # Answer 08

# %%
for i in range(1,11):
    if i == 4:
        continue
    print(i)
# Out:
# 1
# 2
# 3
# 5
# 6
# 7
# 8
# 9
# 10

# %% [markdown]
# # Answer 09

# %%
a="python"
for char in a:
    if char in"aeiou":
        print(char)
# Out:
# o

# %% [markdown]
# # Answer 10

# %%
age = [12,18,25,15]
for i in age:
    if i >= 18:
        print("You Are Adult",i,sep="  ")
    else:
        print("You Are Minor",i,sep="  ")
# Out:
# You Are Minor  12
# You Are Adult  18
# You Are Adult  25
# You Are Minor  15

# %% [markdown]
# # Answer 11

# %%
name=['ALI','SARA','ZAIN']
for i in name:
    if i == 'SARA':
        print(i,"IS PRESENT")
    else:
# Out:
# SARA IS PRESENT

# %% [markdown]
# # Answer 12

# %%
for i in range(1,21):
    if i%3 and i%5 == 0:
        print("FizzBuzz",i,sep="     ")
    else:
        print("None",i,sep="      ")
# Out:
# None      1
# None      2
# None      3
# None      4
# FizzBuzz     5
# None      6
# None      7
# None      8
# None      9
# FizzBuzz     10
# None      11
# None      12
# None      13
# None      14
# None      15
# None      16
# None      17
# None      18
# None      19
# FizzBuzz     20

# %% [markdown]
# # Answer 13

# %%
for i in range(1,11):
    if i%2 == 0:
        print("Even Number",i*2)
    else:
        print("Odd")
# Out:
# Odd
# Even Number 4
# Odd
# Even Number 8
# Odd
# Even Number 12
# Odd
# Even Number 16
# Odd
# Even Number 20

# %% [markdown]
# # Answer 14

# %%
user = ['Ali','Bilal','Ahmed','Sana']
for char in user:
    if char.startswith('A'):
        print(char)
# Out:
# Ali
# Ahmed

# %% [markdown]
# # Answer 15

# %%
count=0
fruit=['apple','mango','apple','banana','apple']
for i in fruit:
    if i == 'apple':
        count+=1
        print("apple ki quantity",count)
# Out:
# apple ki quantity 1
# apple ki quantity 2
# apple ki quantity 3

# %% [markdown]
# # Answer 16

# %%
marks=[45, 80, 30, 95, 40]
for num in marks:
    if num > 50:
        print("PASS",num)
    else:
        print("FAIL",num)
# Out:
# FAIL 45
# PASS 80
# FAIL 30
# PASS 95
# FAIL 40

# %% [markdown]
# # Answer 17

# %%
num=[150, 45, 200, 99, 120]
for i in num:
    if i > 100 and i <200:
        print(i)
# Out:
# 150
# 120

# %% [markdown]
# # Answer 18

# %%
for i in range(10,0,-1):
    if i == 5:
        print("Half Away",i)
    else:
        print(i)
# Out:
# 10
# 9
# 8
# 7
# 6
# Half Away 5
# 4
# 3
# 2
# 1

# %% [markdown]
# # Answer 19

# %%
sum=0
for i in range(1,11):
    sum+=i
print(sum)
# Out:
# 55

# %% [markdown]
# # Answer 20

# %%
user=['123', 'abc', 'admin123', 'xyz']
for i in user:
    if i =="admin123":
        print("Access Granted")
        break
# Out:
# Access Granted
