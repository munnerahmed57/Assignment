# %% [markdown]
# # Student Information

# %%
Name= "Muhammad"
Age= 19
City= "Islamabad"
Student_Status= "Single"

print("Student Information",sep="\n")
print("--------------")
print("Name Of Student Is",Name)
print("Age Of Student Is",Age)
print("City Of Student Is",City)
print("Student_Status Of Student Is",Student_Status)
# Out:
# Student Information
# --------------
# Name Of Student Is Muhammad
# Age Of Student Is 19
# City Of Student Is Islamabad
# Student_Status Of Student Is Single

# %% [markdown]
# # Data Type With Value

# %%
value= "Ahmed"
digit= 20
decimal= 20.0
boolean= True

print("Data Type With Values ")
print("--------------------------")
print(f" Value : {value}, Data_type : {type(value)}")
print(f" Digit : {digit}, Data_type : {type(digit)}")
print(f" Decimal : {decimal}, Data_type : {type(decimal)}")
print(f" Boolean : {boolean}, Data_type : {type(boolean)}")
# Out:
# Data Type With Values
# --------------------------
#  Value : Ahmed, Data_type : <class 'str'>
#  Digit : 20, Data_type : <class 'int'>
#  Decimal : 20.0, Data_type : <class 'float'>
#  Boolean : True, Data_type : <class 'bool'>

# %% [markdown]
# # Arithematic Operation
# - Addition
# - Subtraction
# - Multiplication
# - Divide
# - Modulus
# - Power

# %%
num_1= 10
num_2= 20

print("Addition = ",num_1+num_2)
# Out:
# Addition =  30

# %%
num_1= 10
num_2= 20

print("Subtraction =",num_2 - num_1)
# Out:
# Subtraction = 10

# %%
num_1= 5
num_2= 30

print("Multiplication =",num_1 * num_2)
# Out:
# Multiplication = 150

# %%
num_1= 3
num_2= 40

print("Divide =",num_2 / num_1)
# Out:
# Divide = 13.333333333333334

# %%
num_1= 2
num_2= 20

print("Modulus =",num_2 % num_1)
# Out:
# Modulus = 0

# %%
num_1= 3
num_2= 20

print("Power =",num_2 ** num_1)
# Out:
# Power = 8000

# %% [markdown]
# # Student Marks

# %%
Math= 85
Physics= 65
English= 70
total_num= 100*3
obtain_marks= Math+Physics+English

print("Average Of Subject Is =",obtain_marks / 3,'%')
# Out:
# Average Of Subject Is = 73.33333333333333 %

# %% [markdown]
# # Shopping Bill

# %%
product= "Milk"
price= 150
quantity_kg= 5
total= price*quantity_kg

print("Your Bill Is : ",product,"=",total)
# Out:
# Your Bill Is :  Milk = 750

# %% [markdown]
# # Rectangle Area And Perimeter

# %%
len1= 6
widht= 10
area= len1*widht

print("Area Of Rectangle Is","=",area)
# Out:
# Area Of Rectangle Is = 60

# %%
len2= 7.5
widht2= 9.5
perimeter= 2*(len2 + widht2)

print("Perimeter Of Rectangle Is","=",perimeter)
# Out:
# Perimeter Of Rectangle Is = 34.0

# %% [markdown]
# # Time Converter

# %%
minute= 250
hour= minute / 60
remain_hour = minute % 60

print("Total Hour Is","=",hour)
print("Remining Hour",remain_hour)
# Out:
# Total Hour Is = 4.166666666666667
# Remining Hour 10

# %% [markdown]
# # Student Eligible

# %%
Marks= 70
Attendance= 72

if Marks >= 50 and Attendance >= 75:
    print("Student Is Eligible")
else:
    print("Student Is Not Eligible")
# Out:
# Student Is Not Eligible

# %% [markdown]
# # Logical Operator

# %%
a = True
b = False

print(a and b)
# Out:
# False

# %%
a = True
b = False

print(a or b)
# Out:
# True

# %%
a = True
b = False

print( not a)
# Out:
# False

# %%
a = True
b = False

print(not b)
# Out:
# True

# %% [markdown]
# # Final Challange Student Report

# %%
Stu_name = "Arhaam" 
age = 19

Eng = 76
Physics = 67
Bio = 85

Attendance = 78

print("Student Name Is","=",Stu_name)
print("Age Is","=",age)

print("English Marks Is","=",Eng)
print("Physics Marks Is","=",Physics)
print("Biology Marks Is",Bio)

print("Attendance Is","=",Attendance)

total_marks = Eng+Physics+Bio
avg_mark= total_marks / 3

print("Average Marks Is","=",avg_mark)

eligible = (avg_mark >= 50) and (Attendance >= 75) 

print("Eligible",eligible)
# Out:
# Student Name Is = Arhaam
# Age Is = 19
# English Marks Is = 76
# Physics Marks Is = 67
# Biology Marks Is 85
# Attendance Is = 78
# Average Marks Is = 76.0
# Eligible True
